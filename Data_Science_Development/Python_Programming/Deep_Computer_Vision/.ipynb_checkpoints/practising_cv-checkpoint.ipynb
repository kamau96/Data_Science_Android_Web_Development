# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
image = plt.imread("naruto_image.jpg")

# %%
plt.imshow(image)
plt.axis("off")
# Out:
# (-0.5, 735.5, 980.5, -0.5)
